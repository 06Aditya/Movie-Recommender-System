# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('tmdb_5000_movies.csv')
credits = pd.read_csv('tmdb_5000_credits.csv')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
# ...

# %%
credits.head(1)
# Out:
#    movie_id   title                                               cast  \
# 0     19995  Avatar  [{"cast_id": 242, "character": "Jake Sully", "...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...

# %%
#Merging datasets on basis of title
movies = movies.merge(credits,on='title')

# %%
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ... runtime  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...   162.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
#
#                        tagline   title vote_average vote_count movie_id  \
# 0  Enter the World of Pandora.  Avatar          7.2      11800    19995
#
# ...

# %%
#imp columns for content based recommender system:
#genres
#id
#keywords
#title
#overview
#cast
#crew

movies = movies[['movie_id_x','title','overview','genres','keywords','cast_x','crew_x']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[258], line 10
#       1 #imp columns for content based recommender system:
#       2 #genres
#       3 #id
#    (...)
#       7 #cast
#       8 #crew
# ---> 10 movies = movies[['movie_id_x','title','overview','genres','keywords','cast_x','crew_x']]
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
# ...

# %%
#Main Dataset
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
#checking for missing values
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3096
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# movie_id                   0
# cast                       0
# crew                       0
# dtype: int64

# %%
#dropping missing values
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
#deleting duplicate values
movies.drop_duplicates().duplicated().sum()
# Out:
# 0

# %%
#1 element of genres to see the form of it.
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
#'[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
#['Action','Adventure','Fantasy','SciFi'] ->preprocessing to get genres in this form.

# %%
import ast
#Helper Function
def convert(obj):
    L = []
    p = ast.literal_eval(str(obj))
    for i in p:
#     for i in obj:
        L.append(i["name"])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)

# %%
movies['keywords'] = movies['keywords'].apply(convert)

# %%
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
import ast
#Helper Function for cast
def convert3(obj):
    L = []
    counter = 0
    p = ast.literal_eval(str(obj))
    for i in p:
        if counter !=3:
            L.append(i['name'])
            counter+=1
        else:
            break
    return L

# %%
movies['cast_x'] = movies['cast_x'].apply(convert3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cast_x'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import ast
#Helper Function for crew
def fetchDirector(obj):
    L = []
    p = ast.literal_eval(str(obj))
    for i in p:
        if i['job'] == 'Director':
            L.append(i['name'])
            break
    return L

# %%
movies['crew_x'] = movies['crew_x'].apply(fetchDirector)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'crew_x'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
movies['overview'][0]

# %%
#converting string in overview in list
movies['overview'] = movies['overview'].apply(lambda x:x.split())

# %%
movies.head()

# %%
#Removing space between words in genres,keywords,cast,crew
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast_x'] = movies['cast_x'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew_x'] = movies['crew_x'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast_x'] + movies['crew_x']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\indexes\base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cast_x'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
movies.head()

# %%
new_df = movies[['movie_id_x','title','tags']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[260], line 1
# ----> 1 new_df = movies[['movie_id_x','title','tags']]
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File D:\Program Files\anaconda\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
# ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_7708\3089450492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#    movie_id_x                                     title  \
# 0       19995                                    Avatar
# 1         285  Pirates of the Caribbean: At World's End
# 2      206647                                   Spectre
# 3       49026                     The Dark Knight Rises
# 4       49529                               John Carter
#
#                                                 tags
# 0  i n   t h e   2 2 n d   c e n t u r y ,   a   ...
# 1  c a p t a i n   b a r b o s s a ,   l o n g   ...
# 2  a   c r y p t i c   m e s s a g   f r o m   b ...
# 3  f o l l o w   t h e   d e a t h   o f   d i s ...
# 4  j o h n   c a r t e r   i s   a   w a r - w e ...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_7708\3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
#Stemming using NLTK
#['loved','loving','love']->['love','love','love']
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_7708\3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
new_df['tags']
# Out:
# 0       i n t h e 2 2 n d c e n t u r y , a p a r a p ...
# 1       c a p t a i n b a r b o s s a , l o n g b e l ...
# 2       a c r y p t i c m e s s a g f r o m b o n d ’ ...
# 3       f o l l o w t h e d e a t h o f d i s t r i c ...
# 4       j o h n c a r t e r i s a w a r - w e a r y , ...
#                               ...
# 4816    e l m a r i a c h i j u s t w a n t t o p l a ...
# 4817    a n e w l y w c o u p l e ' h o n e y m o o n ...
# 4818    " s i g n e d , s e a l e d , d e l i v e r e ...
# 4819    w h e n a m b i t i n e w y o r k a t t o r n ...
# 4820    e v e r s i n c t h e s e c o n d g r a d e w ...
# Name: tags, Length: 4818, dtype: object

# %%
#TEXT VECTORIZATION using scikit learn
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 5000 ,stop_words='english' )

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[269], line 1
# ----> 1 vectors = cv.fit_transform(new_df['tags']).toarray()
#
# File D:\Program Files\anaconda\lib\site-packages\sklearn\feature_extraction\text.py:1330, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1322             warnings.warn(
#    1323                 "Upper case characters found in"
#    1324                 " vocabulary while 'lowercase'"
#    1325                 " is True. These entries will not"
#    1326                 " be matched with any documents"
#    1327             )
#    1328             break
# -> 1330 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1332 if self.binary:
#    1333     X.data.fill(1)
#
# ...

# %%
vectors[0]

# %%
cv.get_feature_names()

# %%
#Cosine distance(angle between 2 angles)
#distance is indirectly proportional to similarity.
#Calculating cosine distance using scikit learn
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
def recommend(movie):
    movie_index = new_df[new_df['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)),reverse = True,key = lambda x:x[1])[1:6]
    for i in movies_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend('Batman')
# Out:
# Batman
# Batman
# Batman
# Batman & Robin
# Batman Returns

# %%
import pickle

# %%
pickle.dump(new_df,open('movies.pkl','wb'))

# %%
pickle.dump(new_df.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
new_df.head()
# Out:
#    movie_id_x                                     title  \
# 0       19995                                    Avatar
# 1         285  Pirates of the Caribbean: At World's End
# 2      206647                                   Spectre
# 3       49026                     The Dark Knight Rises
# 4       49529                               John Carter
#
#                                                 tags
# 0  i n t h e 2 2 n d c e n t u r y , a p a r a p ...
# 1  c a p t a i n b a r b o s s a , l o n g b e l ...
# 2  a c r y p t i c m e s s a g f r o m b o n d ’ ...
# 3  f o l l o w t h e d e a t h o f d i s t r i c ...
# 4  j o h n c a r t e r i s a w a r - w e a r y , ...
